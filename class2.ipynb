# %% [markdown]
# workshop day 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import plotly.express as pr
import plotly.graph_objects as go

# %%
df=pd.read_csv('/content/project_dataset.csv.xls')
# Out:
# <ipython-input-7-3b735f426536>:1: DtypeWarning: Columns (70,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/project_dataset.csv.xls')

# %%
df
# Out:
#       Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0        1295781  1998        2      4           2          4  1998-04-02
# 1        1125375  2013        2      5          13          1  2013-05-13
# 2         118824  1993        3      9          25          6  1993-09-25
# 3         634825  1994        4     11          12          6  1994-11-12
# 4        1888125  2017        3      8          17          4  2017-08-17
# ...          ...   ...      ...    ...         ...        ...         ...
# 8627     1415998  2004        3      8          18          3  2004-08-18
# 8628      165171  1993        3      8          29          7  1993-08-29
# 8629     1603068  1989        2      4          20          4  1989-04-20
# 8630      542302  2003        4     11          22          6  2003-11-22
# 8631      952935  2012        1      2           5          7  2012-02-05
#
#      Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# ...

# %%
df1=df.copy

# %%
df.head(10)
# Out:
#    Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0     1295781  1998        2      4           2          4  1998-04-02
# 1     1125375  2013        2      5          13          1  2013-05-13
# 2      118824  1993        3      9          25          6  1993-09-25
# 3      634825  1994        4     11          12          6  1994-11-12
# 4     1888125  2017        3      8          17          4  2017-08-17
# 5     1133769  2014        2      4           2          3  2014-04-02
# 6     1465620  2011        3      8          15          1  2011-08-15
# 7      172607  2019        1      1           6          7  2019-01-06
# 8     1975839  2002        1      1          25          5  2002-01-25
# 9     1912303  2005        3      8           1          1  2005-08-01
#
#   Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                AS                     19930                          AS
# ...

# %%
df.shape
# Out:
# (8632, 110)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'FlightDate', 'Reporting_Airline', 'DOT_ID_Reporting_Airline',
#        'IATA_CODE_Reporting_Airline',
#        ...
#        'Div4WheelsOff', 'Div4TailNum', 'Div5Airport', 'Div5AirportID',
#        'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime',
#        'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum'],
#       dtype='object', length=110)

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Year                  int64
# Quarter               int64
# Month                 int64
# DayofMonth            int64
#                      ...
# Div5WheelsOn        float64
# Div5TotalGTime      float64
# Div5LongestGTime    float64
# Div5WheelsOff       float64
# Div5TailNum         float64
# Length: 110, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8632 entries, 0 to 8631
# Columns: 110 entries, Unnamed: 0 to Div5TailNum
# dtypes: float64(75), int64(18), object(17)
# memory usage: 7.2+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0         Year      Quarter        Month   DayofMonth  \
# count  8.632000e+03  8632.000000  8632.000000  8632.000000  8632.000000
# mean   1.002593e+06  2004.461423     2.522243     6.555375    15.700649
# std    5.759408e+05     9.138776     1.111224     3.447263     8.858891
# min    3.100000e+02  1987.000000     1.000000     1.000000     1.000000
# 25%    5.103392e+05  1997.000000     2.000000     4.000000     8.000000
# 50%    1.010188e+06  2005.000000     3.000000     7.000000    16.000000
# 75%    1.499058e+06  2012.000000     4.000000    10.000000    23.000000
# max    1.999844e+06  2020.000000     4.000000    12.000000    31.000000
#
#          DayOfWeek  DOT_ID_Reporting_Airline  Flight_Number_Reporting_Airline  \
# count  8632.000000               8632.000000                      8632.000000
# mean      3.944972              19924.071594                      1733.797614
# std       1.995385                368.218661                      1652.914879
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8627    False
# 8628    False
# 8629    False
# 8630    False
# 8631    False
# Length: 8632, dtype: bool

# %%
df.isna()
# Out:
#       Unnamed: 0   Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0          False  False    False  False       False      False       False
# 1          False  False    False  False       False      False       False
# 2          False  False    False  False       False      False       False
# 3          False  False    False  False       False      False       False
# 4          False  False    False  False       False      False       False
# ...          ...    ...      ...    ...         ...        ...         ...
# 8627       False  False    False  False       False      False       False
# 8628       False  False    False  False       False      False       False
# 8629       False  False    False  False       False      False       False
# 8630       False  False    False  False       False      False       False
# 8631       False  False    False  False       False      False       False
#
#       Reporting_Airline  DOT_ID_Reporting_Airline  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0             0
# Year                   0
# Quarter                0
# Month                  0
# DayofMonth             0
#                     ...
# Div5WheelsOn        8632
# Div5TotalGTime      8632
# Div5LongestGTime    8632
# Div5WheelsOff       8632
# Div5TailNum         8632
# Length: 110, dtype: int64

# %%
df.isna().sum()/df.shape[0]
# Out:
# Unnamed: 0          0.0
# Year                0.0
# Quarter             0.0
# Month               0.0
# DayofMonth          0.0
#                    ...
# Div5WheelsOn        1.0
# Div5TotalGTime      1.0
# Div5LongestGTime    1.0
# Div5WheelsOff       1.0
# Div5TailNum         1.0
# Length: 110, dtype: float64

# %%
df
# Out:
#       Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0        1295781  1998        2      4           2          4  1998-04-02
# 1        1125375  2013        2      5          13          1  2013-05-13
# 2         118824  1993        3      9          25          6  1993-09-25
# 3         634825  1994        4     11          12          6  1994-11-12
# 4        1888125  2017        3      8          17          4  2017-08-17
# ...          ...   ...      ...    ...         ...        ...         ...
# 8627     1415998  2004        3      8          18          3  2004-08-18
# 8628      165171  1993        3      8          29          7  1993-08-29
# 8629     1603068  1989        2      4          20          4  1989-04-20
# 8630      542302  2003        4     11          22          6  2003-11-22
# 8631      952935  2012        1      2           5          7  2012-02-05
#
#      Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# ...

# %%
df.dropna(axis=1,inplace= True)

# %%
df1
# Out:
# <bound method NDFrame.copy of       Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0        1295781  1998        2      4           2          4  1998-04-02
# 1        1125375  2013        2      5          13          1  2013-05-13
# 2         118824  1993        3      9          25          6  1993-09-25
# 3         634825  1994        4     11          12          6  1994-11-12
# 4        1888125  2017        3      8          17          4  2017-08-17
# ...          ...   ...      ...    ...         ...        ...         ...
# 8627     1415998  2004        3      8          18          3  2004-08-18
# 8628      165171  1993        3      8          29          7  1993-08-29
# 8629     1603068  1989        2      4          20          4  1989-04-20
# 8630      542302  2003        4     11          22          6  2003-11-22
# 8631      952935  2012        1      2           5          7  2012-02-05
#
# ...

# %%
df.shape
# Out:
# (8632, 29)

# %%
data=df.sample(n=500,random_state=42)

# %%
data
# Out:
#       Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 7522     1247985  2000        1      2          15          2  2000-02-15
# 4108      936224  1998        2      6           5          5  1998-06-05
# 2034      573048  2017        4     11          29          3  2017-11-29
# 4162      852275  2010        2      5          30          7  2010-05-30
# 5478      501896  2006        4     11          11          6  2006-11-11
# ...          ...   ...      ...    ...         ...        ...         ...
# 4201     1564357  2000        4     10          17          2  2000-10-17
# 2582       59014  1998        3      7           9          4  1998-07-09
# 2589      934460  2017        1      1          20          5  2017-01-20
# 4818     1390218  2003        3      8          27          3  2003-08-27
# 4050      476183  2009        1      3           4          3  2009-03-04
#
#      Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# ...

# %%
data.shape
data.columns
data.tail
data.head()
# Out:
#       Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 7522     1247985  2000        1      2          15          2  2000-02-15
# 4108      936224  1998        2      6           5          5  1998-06-05
# 2034      573048  2017        4     11          29          3  2017-11-29
# 4162      852275  2010        2      5          30          7  2010-05-30
# 5478      501896  2006        4     11          11          6  2006-11-11
#
#      Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 7522                NW                     19386                          NW
# 4108                WN                     19393                          WN
# 2034                UA                     19977                          UA
# 4162                WN                     19393                          WN
# 5478                OO                     20304                          OO
#
# ...

# %%
data.shape
# Out:
# (500, 29)

# %%
data
# Out:
#       Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 7522     1247985  2000        1      2          15          2  2000-02-15
# 4108      936224  1998        2      6           5          5  1998-06-05
# 2034      573048  2017        4     11          29          3  2017-11-29
# 4162      852275  2010        2      5          30          7  2010-05-30
# 5478      501896  2006        4     11          11          6  2006-11-11
# ...          ...   ...      ...    ...         ...        ...         ...
# 4201     1564357  2000        4     10          17          2  2000-10-17
# 2582       59014  1998        3      7           9          4  1998-07-09
# 2589      934460  2017        1      1          20          5  2017-01-20
# 4818     1390218  2003        3      8          27          3  2003-08-27
# 4050      476183  2009        1      3           4          3  2009-03-04
#
#      Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# ...

# %%
fig=go.figure(data=go.Scatter(x=df('Distance'),y=df('DepTime'),mode='marker',marker=dict(color='red')))   
fig.update_layout(title='Scatter plot for Distance vs Departure time', xaxis_title='Distance',yaxis_title='Departure time')
fig.show()

# %%
line_data=df.groupby('Month')['ArrDelay'].mean().reset_index()

# %%
fig=go.Figure(data=go.Scatter(x=df['Month'],y=df['ArrDelay'],mode='lines',marker=dict(color='green' )))

# %%
line_data
